# %%
import os
import cv2
from Latex.Latex import Latex
import numpy as np
from os import listdir
from skimage import io
import matplotlib.pyplot as plt
from IPython.display import display, Math
import tensorflow as tf

import tensorflow.contrib.legacy_seq2seq as seq2seq

# %%
mean_train = np.load("train_images_mean.npy")
std_train = np.load("train_images_std.npy")

# %%
model = Latex("model", mean_train, std_train, plotting=True)

# %%
# no = 10
# sp = 20
# files = listdir("few_test_eq/test/fractions")
files = listdir("/home/francis/akera/personal/im2latex/nixon/")
for i in range(22):
#     formula = io.imread("few_test_eq/test/fractions/"+files[i])
    formula = io.imread("/home/francis/akera/personal/im2latex/nixon/"+files[i])
    formula = cv2.cvtColor(formula,cv2.COLOR_RGB2GRAY)
    plt.figure(figsize=(20,10))
    plt.imshow(formula, cmap="gray")
    plt.show()
    correct = model.filename2formula(files[i])
    latex = model.predict(formula)
    print("Seq: ", latex['equation'])
# Out:
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '9583 =734                ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{582}{69}-136 = 457     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{723}{76}-483 = 196     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{482}{763}+16 = 570     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{503}{648}-1 = 485      ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{570}{693}#lambda^2-8 #leq 501   ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '530 #leq 148}{              ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '3{368}                   ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{936}{748}#lambda^2-450 #leq 912 ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '3{367}#lambda^2-485 #geq -149     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '5390}{482 = 142          ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{482}{763}+16 = 570     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{3{26}{693}x^4-58 #geq 496 ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{582}{69}-136 = 457     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{582}{69}-136 = 457     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '3{375}{^2-84 #leq 92        ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{386}{ =94}+4 = 572     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{367}{693}#alpha^2-450 #geq 81  ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{382}{673}-64 = 507     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{3{26}{693}x^4-58 #geq 496 ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '#frac{582}{69}-136 = 457     ')
# Start threshold:
# Start bounding boxes:
# ('Seq: ', '{3103}+ 1584    262      ')
